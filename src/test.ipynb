# %%
import pandas as pd

# embeddings = pd.read_pickle('../data/entities_embeddings.pkl')
embeddings = pd.read_pickle('../data/smiles_embeddings.pkl')


# 查看基本信息
print("数据类型:", type(embeddings))
print("形状 (行, 列):", embeddings.shape)
print("\n前5行:")
print(embeddings.head())

print("\n列名:")
print(embeddings.columns.tolist())
print("\n示例实体 ID 和可能的名称字段:")
sample_row = embeddings.iloc[0]
for col in embeddings.columns:
    print(f"  {col}: {sample_row[col]}")
# Out:
# 数据类型: <class 'pandas.core.frame.DataFrame'>
# 形状 (行, 列): (7163, 7)
#
# 前5行:
#             id                                             SMILES  x_index  \
# 0  drug::14012                                               [Cu]    14012
# 1  drug::14013                                                  O    14013
# 2  drug::14014  O.CC1(C)O[C@@H]2CC3[C@@H]4C[C@H](F)C5=CC(=O)C=...    14014
# 3  drug::14015  C[C@@H]1C[C@H]2[C@@H]3[C@H](Cl)CC4=CC(=O)C=C[C...    14015
# 4  drug::14016  C[C@H]1C[C@H]2[C@@H]3CC[C@H](C(C)=O)[C@@]3(C)C...    14016
#
#   x_type         x_name     x_id  \
# 0   drug         Copper  DB09130
# 1   drug         Oxygen  DB09140
# 2   drug    Flunisolide  DB00180
# 3   drug  Alclometasone  DB00240
# 4   drug      Medrysone  DB00253
#
#                                            embedding
# 0  [-1.3717145919799805, -1.4564843972524006, -2....
# 1  [-1.269039233525594, -1.4842836062113445, -2.0...
# 2  [-2.5624887882524234, -2.247069711897783, -2.6...
# ...
